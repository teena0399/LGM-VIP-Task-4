# %% [markdown]
# # Lets Grow More
# # Task 2- Image to Pencil Sketch with Python
# # By Teena Borse

# %%
pip install opencv-contrib-python-headless
# Out:
# Collecting opencv-contrib-python-headless
#   Downloading opencv_contrib_python_headless-4.5.4.58-cp39-cp39-win_amd64.whl (41.9 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\priyanka\appdata\local\programs\python\python39\lib\site-packages (from opencv-contrib-python-headless) (1.21.4)
# Installing collected packages: opencv-contrib-python-headless
# Successfully installed opencv-contrib-python-headless-4.5.4.58
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\priyanka\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image=cv2.imread("nature.jpg")

# %%
# Read the image in RGB format

im_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(im_rgb)
plt.title("Original Image")
plt.axis("off");

# %%
# Convert the original image to grayscale image

gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,6))
plt.imshow(gray_image,cmap="gray")
plt.title("GrayScale Image")
plt.axis("off");

# %%
# Inverting image 

inverted_image=255-gray_image
plt.figure(figsize=(10,6))
plt.imshow(inverted_image,cmap="gray")
plt.title("Inverted Image")
plt.axis("off");

# %%
# Blur image

blur=cv2.GaussianBlur(inverted_image,(21,21),0)
plt.figure(figsize=(10,6))
plt.imshow(blur,cmap="gray")
plt.title("Smoothen Image")
plt.axis("off");

# %%
# Convert image to Pencil Sketch

sketch=cv2.divide(gray_image,255-blur,scale=255)
plt.figure(figsize=(10,6))
plt.imshow(sketch,cmap="gray")
plt.title("Final Sketch Image")
plt.axis("off");
